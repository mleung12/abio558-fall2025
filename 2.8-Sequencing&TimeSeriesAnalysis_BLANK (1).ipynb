# %% [markdown]
# # 2.8- Sequencing data and time series analysis
#
# ### Learning goals for today
# 1. Load, visualize and understand RNA sequencing data
# 2. Annotating scRNAseq data using marker genes
# 3. Bonus: Analyzing time series data
#
# ---
# ### How to use this notebook during class
# - Follow along as we go
# - Use your **Cards** to indicate where you're at:
#     - A **🟩Green card** means you are caught up with Max and **ready to help your classmates**
#     - A **🟥Red card** means you are stuck and need help
# - <span style='color:red;'>EXERCISE</span> — work on this problem by yourself, or try with a partner if you get stuck
# ---

# %% [markdown]
# First let's import some libraries we will use today. Remember if you don't have a library installed you can pip install it with:
#
# %pip install *package_name*

# %% [markdown]
# ## 1) scRNAseq data - looking at it
#
# Download `tags.csv` and `ct.csv` from brightspace or the course github
#
# Data originally from: https://www.pnas.org/doi/full/10.1073/pnas.1507125112

# %%
# %pip install scanpy
# %pip install igraph
# Out:
# Collecting scanpy
#   Downloading scanpy-1.11.5-py3-none-any.whl.metadata (9.3 kB)
# Collecting anndata>=0.8 (from scanpy)
#   Downloading anndata-0.12.4-py3-none-any.whl.metadata (9.9 kB)
# Collecting h5py>=3.7.0 (from scanpy)
#   Downloading h5py-3.15.1-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: joblib in c:\users\meaga\miniconda3\lib\site-packages (from scanpy) (1.5.2)
# Collecting legacy-api-wrap>=1.4.1 (from scanpy)
#   Downloading legacy_api_wrap-1.4.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: matplotlib>=3.7.5 in c:\users\meaga\miniconda3\lib\site-packages (from scanpy) (3.10.6)
# Collecting natsort (from scanpy)
#   Using cached natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting networkx>=2.7.1 (from scanpy)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting numba!=0.62.0rc1,>=0.57.1 (from scanpy)
#   Downloading numba-0.62.1-cp312-cp312-win_amd64.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\meaga\miniconda3\lib\site-packages (from scanpy) (2.3.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\meaga\miniconda3\lib\site-packages (from scanpy) (23.2)
# Requirement already satisfied: pandas>=1.5.3 in c:\users\meaga\miniconda3\lib\site-packages (from scanpy) (2.3.3)
# Collecting patsy!=1.0.0 (from scanpy)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting pynndescent>=0.5.13 (from scanpy)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: scikit-learn>=1.1.3 in c:\users\meaga\miniconda3\lib\site-packages (from scanpy) (1.7.2)
# Requirement already satisfied: scipy>=1.8.1 in c:\users\meaga\miniconda3\lib\site-packages (from scanpy) (1.16.2)
# Requirement already satisfied: seaborn>=0.13.2 in c:\users\meaga\miniconda3\lib\site-packages (from scanpy) (0.13.2)
# Collecting session-info2 (from scanpy)
#   Downloading session_info2-0.2.3-py3-none-any.whl.metadata (3.4 kB)
# Collecting statsmodels>=0.14.5 (from scanpy)
#   Downloading statsmodels-0.14.5-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: tqdm in c:\users\meaga\miniconda3\lib\site-packages (from scanpy) (4.66.2)
# Requirement already satisfied: typing-extensions in c:\users\meaga\miniconda3\lib\site-packages (from scanpy) (4.15.0)
# Collecting umap-learn>=0.5.6 (from scanpy)
#   Downloading umap_learn-0.5.9.post2-py3-none-any.whl.metadata (25 kB)
# Collecting array-api-compat>=1.7.1 (from anndata>=0.8->scanpy)
#   Downloading array_api_compat-1.12.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting packaging>=21.3 (from scanpy)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata>=0.8->scanpy)
#   Downloading zarr-3.1.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\meaga\miniconda3\lib\site-packages (from matplotlib>=3.7.5->scanpy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\meaga\miniconda3\lib\site-packages (from matplotlib>=3.7.5->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\meaga\miniconda3\lib\site-packages (from matplotlib>=3.7.5->scanpy) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\meaga\miniconda3\lib\site-packages (from matplotlib>=3.7.5->scanpy) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\meaga\miniconda3\lib\site-packages (from matplotlib>=3.7.5->scanpy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\meaga\miniconda3\lib\site-packages (from matplotlib>=3.7.5->scanpy) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\meaga\miniconda3\lib\site-packages (from matplotlib>=3.7.5->scanpy) (2.9.0.post0)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba!=0.62.0rc1,>=0.57.1->scanpy)
#   Downloading llvmlite-0.45.1-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\meaga\miniconda3\lib\site-packages (from pandas>=1.5.3->scanpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\meaga\miniconda3\lib\site-packages (from pandas>=1.5.3->scanpy) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\meaga\miniconda3\lib\site-packages (from scikit-learn>=1.1.3->scanpy) (3.6.0)
# Requirement already satisfied: colorama in c:\users\meaga\miniconda3\lib\site-packages (from tqdm->scanpy) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\meaga\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.7.5->scanpy) (1.17.0)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Collecting numcodecs>=0.14 (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy)
#   Downloading numcodecs-0.16.3-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: pyyaml in c:\users\meaga\miniconda3\lib\site-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (6.0.3)
# Collecting crc32c>=2.7 (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy)
#   Downloading crc32c-2.8-cp312-cp312-win_amd64.whl.metadata (8.0 kB)
# Downloading scanpy-1.11.5-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------ --------------------------------- 0.4/2.1 MB 7.4 MB/s eta 0:00:01
#    ------------- -------------------------- 0.7/2.1 MB 7.3 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 10.3 MB/s eta 0:00:00
# Downloading anndata-0.12.4-py3-none-any.whl (170 kB)
#    ---------------------------------------- 0.0/170.7 kB ? eta -:--:--
#    --------------------------------------- 170.7/170.7 kB 10.0 MB/s eta 0:00:00
# Downloading h5py-3.15.1-cp312-cp312-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    -------- ------------------------------- 0.6/2.9 MB 18.8 MB/s eta 0:00:01
#    --------------------- ------------------ 1.5/2.9 MB 19.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.5/2.9 MB 19.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 18.4 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.4.1-py3-none-any.whl (10.0 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------------------- -------------------- 1.0/2.0 MB 31.7 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 32.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 21.8 MB/s eta 0:00:00
# Downloading numba-0.62.1-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------------- -------------------------- 0.9/2.7 MB 28.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.0/2.7 MB 25.9 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 21.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 17.5 MB/s eta 0:00:00
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.5 kB ? eta -:--:--
#    ---------------------------------------- 66.5/66.5 kB ? eta 0:00:00
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
#    ---------------------------------------- 0.0/233.3 kB ? eta -:--:--
#    --------------------------------------- 233.3/233.3 kB 13.9 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.9 kB ? eta -:--:--
#    ---------------------------------------- 56.9/56.9 kB 2.9 MB/s eta 0:00:00
# Downloading statsmodels-0.14.5-cp312-cp312-win_amd64.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.6 MB 24.4 MB/s eta 0:00:01
#    ------ --------------------------------- 1.6/9.6 MB 17.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.5/9.6 MB 17.6 MB/s eta 0:00:01
#    ------------ --------------------------- 3.1/9.6 MB 18.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.0/9.6 MB 17.0 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.6 MB 16.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.5/9.6 MB 16.7 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.6 MB 17.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.1/9.6 MB 16.8 MB/s eta 0:00:01
#    -------------------------------- ------- 7.9/9.6 MB 16.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.6/9.6 MB 16.6 MB/s eta 0:00:01
#    -------------------------------------- - 9.3/9.6 MB 16.5 MB/s eta 0:00:01
#    ---------------------------------------  9.6/9.6 MB 16.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 15.4 MB/s eta 0:00:00
# Downloading umap_learn-0.5.9.post2-py3-none-any.whl (90 kB)
#    ---------------------------------------- 0.0/90.1 kB ? eta -:--:--
#    ---------------------------------------- 90.1/90.1 kB 5.0 MB/s eta 0:00:00
# Using cached natsort-8.4.0-py3-none-any.whl (38 kB)
# Downloading session_info2-0.2.3-py3-none-any.whl (16 kB)
# Downloading array_api_compat-1.12.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.2 kB ? eta -:--:--
#    ---------------------------------------- 58.2/58.2 kB 3.2 MB/s eta 0:00:00
# Downloading llvmlite-0.45.1-cp312-cp312-win_amd64.whl (38.1 MB)
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#     --------------------------------------- 0.7/38.1 MB 15.5 MB/s eta 0:00:03
#    - -------------------------------------- 1.5/38.1 MB 18.9 MB/s eta 0:00:02
#    -- ------------------------------------- 2.3/38.1 MB 17.9 MB/s eta 0:00:02
#    --- ------------------------------------ 3.1/38.1 MB 16.3 MB/s eta 0:00:03
#    --- ------------------------------------ 3.8/38.1 MB 16.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.7/38.1 MB 16.5 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.4/38.1 MB 16.6 MB/s eta 0:00:02
#    ------ --------------------------------- 6.3/38.1 MB 16.9 MB/s eta 0:00:02
#    ------- -------------------------------- 7.2/38.1 MB 17.1 MB/s eta 0:00:02
#    -------- ------------------------------- 7.9/38.1 MB 17.4 MB/s eta 0:00:02
#    --------- ------------------------------ 8.7/38.1 MB 16.9 MB/s eta 0:00:02
#    --------- ------------------------------ 9.5/38.1 MB 16.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 9.7/38.1 MB 16.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 10.3/38.1 MB 16.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 11.0/38.1 MB 16.0 MB/s eta 0:00:02
#    ------------ --------------------------- 11.8/38.1 MB 15.6 MB/s eta 0:00:02
#    ------------- -------------------------- 12.5/38.1 MB 16.0 MB/s eta 0:00:02
#    ------------- -------------------------- 13.3/38.1 MB 15.6 MB/s eta 0:00:02
#    -------------- ------------------------- 14.0/38.1 MB 15.2 MB/s eta 0:00:02
#    --------------- ------------------------ 14.7/38.1 MB 15.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 15.5/38.1 MB 15.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 16.1/38.1 MB 14.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 17.0/38.1 MB 14.9 MB/s eta 0:00:02
#    ------------------ --------------------- 17.9/38.1 MB 15.2 MB/s eta 0:00:02
#    ------------------- -------------------- 18.7/38.1 MB 14.9 MB/s eta 0:00:02
#    -------------------- ------------------- 19.5/38.1 MB 15.2 MB/s eta 0:00:02
#    --------------------- ------------------ 20.1/38.1 MB 15.6 MB/s eta 0:00:02
#    --------------------- ------------------ 20.9/38.1 MB 15.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.7/38.1 MB 16.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 22.4/38.1 MB 15.6 MB/s eta 0:00:02
#    ------------------------ --------------- 23.1/38.1 MB 15.6 MB/s eta 0:00:01
#    ------------------------- -------------- 24.0/38.1 MB 16.0 MB/s eta 0:00:01
#    ------------------------- -------------- 24.8/38.1 MB 16.4 MB/s eta 0:00:01
#    -------------------------- ------------- 25.7/38.1 MB 16.8 MB/s eta 0:00:01
#    --------------------------- ------------ 26.4/38.1 MB 16.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.2/38.1 MB 16.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.0/38.1 MB 16.4 MB/s eta 0:00:01
#    ------------------------------ --------- 28.9/38.1 MB 16.8 MB/s eta 0:00:01
#    ------------------------------- -------- 29.7/38.1 MB 16.8 MB/s eta 0:00:01
#    -------------------------------- ------- 30.7/38.1 MB 17.2 MB/s eta 0:00:01
#    --------------------------------- ------ 31.5/38.1 MB 17.7 MB/s eta 0:00:01
#    --------------------------------- ------ 32.0/38.1 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 32.6/38.1 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.2/38.1 MB 16.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 33.9/38.1 MB 16.4 MB/s eta 0:00:01
#    ------------------------------------ --- 34.4/38.1 MB 16.0 MB/s eta 0:00:01
#    ------------------------------------ --- 35.1/38.1 MB 16.0 MB/s eta 0:00:01
#    ------------------------------------- -- 35.8/38.1 MB 15.2 MB/s eta 0:00:01
#    -------------------------------------- - 36.6/38.1 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  37.6/38.1 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  38.1/38.1 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  38.1/38.1 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------- 38.1/38.1 MB 13.6 MB/s eta 0:00:00
# Downloading zarr-3.1.3-py3-none-any.whl (276 kB)
#    ---------------------------------------- 0.0/276.4 kB ? eta -:--:--
#    ---------------------------------------- 276.4/276.4 kB 8.6 MB/s eta 0:00:00
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.3-cp312-cp312-win_amd64.whl (806 kB)
#    ---------------------------------------- 0.0/806.3 kB ? eta -:--:--
#    --------------------------------------  798.7/806.3 kB 25.4 MB/s eta 0:00:01
#    --------------------------------------- 806.3/806.3 kB 16.9 MB/s eta 0:00:00
# Downloading crc32c-2.8-cp312-cp312-win_amd64.whl (66 kB)
#    ---------------------------------------- 0.0/66.6 kB ? eta -:--:--
#    ---------------------------------------- 66.6/66.6 kB ? eta 0:00:00
# Installing collected packages: session-info2, patsy, packaging, numcodecs, networkx, natsort, llvmlite, legacy-api-wrap, h5py, donfig, crc32c, array-api-compat, numba, zarr, statsmodels, pynndescent, umap-learn, anndata, scanpy
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
# Successfully installed anndata-0.12.4 array-api-compat-1.12.0 crc32c-2.8 donfig-0.8.1.post1 h5py-3.15.1 legacy-api-wrap-1.4.1 llvmlite-0.45.1 natsort-8.4.0 networkx-3.5 numba-0.62.1 numcodecs-0.16.3 packaging-25.0 patsy-1.0.2 pynndescent-0.5.13 scanpy-1.11.5 session-info2-0.2.3 statsmodels-0.14.5 umap-learn-0.5.9.post2 zarr-3.1.3
# Note: you may need to restart the kernel to use updated packages.
# Collecting igraph
#   Downloading igraph-1.0.0-cp39-abi3-win_amd64.whl.metadata (4.5 kB)
# Collecting texttable>=1.6.2 (from igraph)
#   Using cached texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Downloading igraph-1.0.0-cp39-abi3-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB 165.2 kB/s eta 0:00:20
#     --------------------------------------- 0.1/3.2 MB 491.5 kB/s eta 0:00:07
#    ------- -------------------------------- 0.6/3.2 MB 3.1 MB/s eta 0:00:01
#    -------------- ------------------------- 1.1/3.2 MB 5.2 MB/s eta 0:00:01
#    ------------------------ --------------- 2.0/3.2 MB 7.0 MB/s eta 0:00:01
#    --------------------------------- ------ 2.7/3.2 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  3.2/3.2 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 8.2 MB/s eta 0:00:00
# Using cached texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph
# Successfully installed igraph-1.0.0 texttable-1.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scanpy
import anndata

# %% [markdown]
# Generally it is best to not keep data in your code repository, and GitHub cannot sync large files. So let's point our code to the file path on the computer

# %%
data_directory = '/Users/meaga/Downloads'
filepath_tags = os.path.join(data_directory, 'tags.csv')
filepath_celltypes = os.path.join(data_directory, 'ct.csv')

os.path.exists(filepath_tags)
# Out:
# True

# %% [markdown]
# First we'll use pandas to load the data. There are two things we'll load:
# 1. The gene counts matrix, which has cells along the rows and genes along the columns
# 2. The cell type array, which has labels for each annotated cell type

# %%
reads_df = pd.read_csv(filepath_tags,index_col=0).T
reads_df.head()
# Out:
#             1/2-SBSRNA4  A1BG  A1BG-AS1  A1CF  A2LD1  A2M  A2ML1  A2MP1  \
# GSM1658365            0     0         0     0      0    0      0      0
# GSM1658366            0     0         0     0      0    0      0      0
# GSM1658364            0     0         0     0      0    0      0      0
# GSM1658363            0     0         0     0      0    0      0      0
# GSM1658362            0     0         0     0      0    0      0      0
#
#             A4GALT  A4GNT  ...  ZWINT  ZXDA  ZXDB  ZXDC  ZYG11A  ZYG11B  ZYX  \
# GSM1658365       0      0  ...      0    28     0     5       0      67    9
# GSM1658366       0      0  ...      0     0     0    22       0       0    6
# GSM1658364       0      0  ...      0     0     0     0       0       0    0
# GSM1658363       0      0  ...      0     0     0    18       0       0    0
# GSM1658362       0      0  ...      0     0     0     8       0       0    0
#
#             ZZEF1  ZZZ3  tAKR
# GSM1658365      0     0     0
# GSM1658366      0     7     0
# GSM1658364      0     0     0
# GSM1658363      0     4     0
# GSM1658362      0     0     0
#
# [5 rows x 22085 columns]

# %% [markdown]
# These data have already been annotated. Let's look at the cell types in the annotation

# %%
cell_types = pd.read_csv(filepath_celltypes, index_col=0)
cell_types.value_counts()
# Out:
# cell_type
# neurons              131
# fetal_quiescent      110
# astrocytes            62
# oligodendrocytes      38
# fetal_replicating     25
# endothelial           20
# OPC                   18
# microglia             16
# Name: count, dtype: int64

# %% [markdown]
# This is a big matrix, and scanpy uses a special data type to hold this and run calcuations on it called an Annotated Data (AnnData) object
#
# Let's make an AnnData (Annotated Data) object from our two dataframes

# %%
adata = anndata.AnnData(reads_df, obs=cell_types)
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 420 × 22085
#     obs: 'cell_type'

# %% [markdown]
# Let's do some standard preprocessing steps to remove cells that don't have many genes, and genes that don't show up in many cells

# %%
scanpy.pp.filter_cells(adata, min_genes=100)
scanpy.pp.filter_genes(adata, min_cells=3)

print(adata)
# Out:
# AnnData object with n_obs × n_vars = 420 × 19231
#     obs: 'cell_type', 'n_genes'
#     var: 'n_cells'

# %% [markdown]
# Notice that when we do stuff to adata, it modifies the object **in place** and adds new observations to the table
#
# The next step is to normalize the read counts within a cell to that cell's median reads. That lets us compare amount of gene expression across cells that maybe just have more mRNA around for whatever reason.
#
# Then we'll transform to log(count+1). Log transforming helps make the variances more comparable for genes that may differ in abundance over orders of magnitude.

# %%
# median count depth normalization
scanpy.pp.normalize_total(adata)

scanpy.pp.log1p(adata)
adata
# Out:
# AnnData object with n_obs × n_vars = 420 × 19231
#     obs: 'cell_type', 'n_genes'
#     var: 'n_cells'
#     uns: 'log1p'

# %% [markdown]
# **Feature selection:** Let's add tags to indicate "highly variable genes," to help us focus on genes that are differentially expressed across the cells. We will use this for visualizing lower dimensional representations (like UMAP) and for clustering

# %%
scanpy.pp.highly_variable_genes(adata, n_top_genes=2000)
adata
# Out:
# AnnData object with n_obs × n_vars = 420 × 19231
#     obs: 'cell_type', 'n_genes'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'log1p', 'hvg'

# %% [markdown]
# Let's do PCA to get a sense of the dimensionality of the data

# %%
scanpy.tl.pca(adata)
scanpy.pl.pca_variance_ratio(adata, n_pcs=50, log=True)

# %% [markdown]
# Let's look at a lower dimensional representation of the gene expression profiles of these cells using UMAP. We will use pre-annotated cell types to color the points

# %%
# compute neighborhood graph (~distance matrix)
scanpy.pp.neighbors(adata)

# project data into UMAP coordinates
scanpy.tl.umap(adata)

# display UMAP
scanpy.pl.umap(adata, color='cell_type', size=100, alpha=0.8)

# %% [markdown]
# ## 2) scRNAseq data - clustering and annotating
# What if we didn't have cell type annotations? Let's see how we could make our own using clustering and known marker genes

# %% [markdown]
# Now let's cluster our cells using the Leiden method. We can control how fine-scale the clustering is with the `resolution` parameter.

# %%
scanpy.tl.leiden(adata, flavor='igraph', resolution=1.26)
scanpy.pl.umap(adata, color='leiden')

# %% [markdown]
# ### <span style='color:red;'>EXERCISE 1</span>: Find a good resolution value  (5 min)
#
# Play with the `resolution` parameter to find a good value that gives use approximately the right number of clusters. You can iterate on this while trying to assign clusters to cell types

# %% [markdown]
# Suppose we have marker genes for each of the cell types we are interested in. We can tell scanpy about these marker genes using a dictionary like this one:

# %%
marker_genes_dict = {
    "OPC": ["PCDH15", "MEGF11", "LHFPL3", "PDGFRA"],
    "Astrocytes": ["SLC14A1", "GLIS3", "GLI3", "CTH", "HGF"],
    "Endothelial": ["APOLD1", "FLT1", "A2M", "TM4SF1"],
    "microglia": ["CCL4", "GPR183", "CD83", "CD14", "CSF1R"],
    "neurons": ["KCNK1", "NELL1", "COBL", "DCN", "DLX2", "DLX5", "SST", "PNOC"],
    "oligodendrocytes": ["DAAM2", "ASPA", "MAL", "MAG", "GSN"],
}

# %% [markdown]
# Now let's see how our clusters line up to real cell types using a dotplot

# %%
scanpy.pl.dotplot(adata, marker_genes_dict, groupby="leiden")

# %%
cluster_mapping_dictionary =     {
                                  "0": "?",
                                  "1": "Endothelial",
                                  "2": "Astrocytes",
                                  "3": "Neurons",
                                  "4": "Oligodendrocytes",
                                  "5": "OPC",
                                  "6": "?",
                                  "7": "?",
                                 }

# %% [markdown]
# Let's add an observation to the andata object to hold our putative cell types. We'll do this using the pandas .map() function on our dictionary
#
# Then we'll look at the UMAP, colored by putative cell type

# %%
adata.obs['cell_type_putative'] = adata.obs['leiden'].map(cluster_mapping_dictionary)

scanpy.pl.umap(adata, color='cell_type_putative')

# %% [markdown]
# You can imagine that for your own data you would want to iterate on clustering, labeling, and identifying marker genes until you are happy with your clusters

# %% [markdown]
# Let's take a rough look at differentially expressed genes among these groups

# %%
scanpy.tl.rank_genes_groups(adata, "cell_type", method='wilcoxon')
scanpy.pl.rank_genes_groups(adata)

# %% [markdown]
# Let's make volcano plot

# %%
result = scanpy.get.rank_genes_groups_df(adata, group=['neurons'], pval_cutoff=0.01)
result.head
# Out:
# <bound method NDFrame.head of         names     scores  logfoldchanges         pvals     pvals_adj
# 0        MEG3  14.894347        7.395569  3.586723e-50  6.897628e-46
# 1      GABRG2  14.492606        6.931857  1.349250e-47  9.629404e-44
# 2      SNAP25  14.464840        6.363084  2.020746e-47  9.629404e-44
# 3     TMEM130  14.461370        6.710864  2.125277e-47  9.629404e-44
# 4      GABRB2  14.450089        7.585397  2.503615e-47  9.629404e-44
# ...       ...        ...             ...           ...           ...
# 4980  HNRNPH1  -8.879514       -1.293640  6.715307e-19  4.035690e-17
# 4981    H3F3B  -9.328544       -1.850932  1.073351e-20  8.256647e-19
# 4982      SCD  -9.388414       -4.282340  6.091006e-21  4.781067e-19
# 4983    NHSL1 -10.308600       -5.798229  6.443250e-25  8.604870e-23
# 4984     NFIA -10.420533       -4.370446  1.998302e-25  2.933538e-23
#
# [4985 rows x 5 columns]>

# %%
result["-logp"] = -np.log(result["pvals_adj"].astype('float'))
result
# Out:
#         names     scores  logfoldchanges         pvals     pvals_adj  \
# 0        MEG3  14.894347        7.395569  3.586723e-50  6.897628e-46
# 1      GABRG2  14.492606        6.931857  1.349250e-47  9.629404e-44
# 2      SNAP25  14.464840        6.363084  2.020746e-47  9.629404e-44
# 3     TMEM130  14.461370        6.710864  2.125277e-47  9.629404e-44
# 4      GABRB2  14.450089        7.585397  2.503615e-47  9.629404e-44
# ...       ...        ...             ...           ...           ...
# 4980  HNRNPH1  -8.879514       -1.293640  6.715307e-19  4.035690e-17
# 4981    H3F3B  -9.328544       -1.850932  1.073351e-20  8.256647e-19
# 4982      SCD  -9.388414       -4.282340  6.091006e-21  4.781067e-19
# 4983    NHSL1 -10.308600       -5.798229  6.443250e-25  8.604870e-23
# 4984     NFIA -10.420533       -4.370446  1.998302e-25  2.933538e-23
#
#            -logp
# 0     103.987737
# 1      99.048923
# 2      99.048923
# 3      99.048923
# 4      99.048923
# ...          ...
# 4980   37.748769
# 4981   41.638098
# 4982   42.184453
# 4983   50.807129
# 4984   51.883248
#
# [4985 rows x 6 columns]

# %%
fh, ax = plt.subplots(1,1,figsize=(4,4))
ax.scatter(x=result['logfoldchanges'],
           y=result['-logP'],
           marker='.')
ax.set_xlabel('log2(FC)')
ax.set_ylabel('-log10(p)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '-logP'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 3
#       1 fh, ax = plt.subplots(1,1,figsize=(4,4))
#       2 ax.scatter(x=result['logfoldchanges'],
# ----> 3            y=result['-logP'],
#       4            marker='.')
#       5 ax.set_xlabel('log2(FC)')
#       6 ax.set_ylabel('-log10(p)')
#
# File ~\miniconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: '-logP'

# %% [markdown]
# # BONUS: time series analysis

# %% [markdown]
# ## 3) Time series data -  Examining extracellular spiking data

# %% [markdown]
# ### Detect spike times
# Let's say we want to detect the times when the neuron fired an action potential (spike).
#
# Steps:
# 1. Filter the signal: remove low-frequency changes in baseline using a **high-pass filter**
# 2. Find the points where the trace goes beyond some threshold value
# 3. Make sure you aren't double counting spikes!

# %% [markdown]
# ## 4) Spike triggered average of a neuron
#
# Reliable spike detection is beyond the scope of this class, so we're going to skip some intervening steps and start with already detected spikes.
# A common way to represent spike times is a vector that is zero everywhere except the time points where the spike occurred.
#
# Let's load some processed spike time data, alongside the visual stimulus that was shown to the neuron. These data are from a neuron in blowfly called H1 that is sensitive to motion in the visual world. The stimulus is reported as the rotational velocity (in degrees/second). Both the stimulus and spike times have a sampling period of 2 msec.

# %% [markdown]
# `'stim'` is the stimulus
#
# `'rho'` is the spike binary vector
#
# Let's make some variables to be able to refer to each of these a bit more easily. We'll also make a vector of timestamps based on the knowledge that each time step is 2 msec

# %% [markdown]
# Now let's jsut plot a bit of the stim and response trace to see what we're looking at

# %% [markdown]
# We're going to figure out what makes this neuron spike. To do that we will compute the **spike triggered average stimulus** this, as the name implies is the average stimulus that triggers a spike. The strategy is straightforward:
# 1. Define some window of time to look backwards (let's say 300 datapoints, or 600 msec)
# 2. Find all the spike times
# 3. Pull out the stimulus for the 300 datapoints preceding each spike
# 4. Average all the stimuli together

# %% [markdown]
# Now let's plot our spike triggered average. To visualize it, we need a time vector for the x axis...
