# %%
#MAKE HISTOGRAM - WORK IN PROGRESS

# Data for the histogram
data = bar_position

# Plotting a basic histogram
plt.hist(data, bins=10, color='blue', edgecolor='black')

# Adding labels and title
plt.xlabel('Position of bar (deg.)')
plt.ylabel('Frequency')
plt.title(' ')

# Display the plot
plt.show()

# %%
#BOOTSTRAP DATA - VERY INCOMPLETE

import pandas as pd
import numpy as np

#df = fly tracking data

def create_bootstrap_sample_df(df):
    """Returns a bootstrap sample of a Pandas DataFrame."""
    return df.sample(n=len(df), replace=True)

# Example usage:
bootstrap_sample_df = create_bootstrap_sample_df(df)
print(f"Original DataFrame head:\n{df.head()}")
print(f"Bootstrap Sample DataFrame head:\n{bootstrap_sample_df.head()}")
